# %% [markdown]
# **Mistral Models Available **

# %%
# !pip uninstall mistralai -y
# !pip install mistralai==0.4.2
# Out:
# Found existing installation: mistralai 0.4.2
# Uninstalling mistralai-0.4.2:
#   Successfully uninstalled mistralai-0.4.2
# Collecting mistralai==0.4.2
#   Using cached mistralai-0.4.2-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: httpx<1,>=0.25 in /usr/local/lib/python3.12/dist-packages (from mistralai==0.4.2) (0.28.1)
# Requirement already satisfied: orjson<3.11,>=3.9.10 in /usr/local/lib/python3.12/dist-packages (from mistralai==0.4.2) (3.10.18)
# Requirement already satisfied: pydantic<3,>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mistralai==0.4.2) (2.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25->mistralai==0.4.2) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25->mistralai==0.4.2) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25->mistralai==0.4.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25->mistralai==0.4.2) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25->mistralai==0.4.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.5.2->mistralai==0.4.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.5.2->mistralai==0.4.2) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.5.2->mistralai==0.4.2) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.5.2->mistralai==0.4.2) (0.4.2)
# Using cached mistralai-0.4.2-py3-none-any.whl (20 kB)
# Installing collected packages: mistralai
# Successfully installed mistralai-0.4.2

# %%
import os
from mistralai.client import MistralClient
from google.colab import userdata

# Get your API key from Colab secrets
api_key = userdata.get('MISTRAL_API_KEY')

# Initialize the new client
client = MistralClient(api_key=api_key)

models = client.list_models()

print("Available Mistral AI models:")
for model in models.data:
    print(model.id)
# Out:
# Available Mistral AI models:
# mistral-medium-2505
# mistral-medium-2508
# mistral-medium-latest
# mistral-medium
# open-mistral-nemo
# open-mistral-nemo-2407
# mistral-tiny-2407
# mistral-tiny-latest
# mistral-large-2411
# pixtral-large-2411
# pixtral-large-latest
# mistral-large-pixtral-2411
# codestral-2508
# codestral-latest
# devstral-small-2507
# devstral-medium-2507
# devstral-2512
# mistral-vibe-cli-latest
# devstral-medium-latest
# devstral-latest
# labs-devstral-small-2512
# devstral-small-latest
# mistral-small-2506
# mistral-small-latest
# labs-mistral-small-creative
# magistral-medium-2509
# magistral-medium-latest
# magistral-small-2509
# magistral-small-latest
# voxtral-mini-2507
# voxtral-mini-latest
# voxtral-small-2507
# voxtral-small-latest
# mistral-large-2512
# mistral-large-latest
# ministral-3b-2512
# ministral-3b-latest
# ministral-8b-2512
# ministral-8b-latest
# ministral-14b-2512
# ministral-14b-latest
# open-mistral-7b
# mistral-tiny
# mistral-tiny-2312
# pixtral-12b-2409
# pixtral-12b
# pixtral-12b-latest
# ministral-3b-2410
# ministral-8b-2410
# codestral-2501
# codestral-2412
# codestral-2411-rc5
# mistral-small-2501
# mistral-embed-2312
# mistral-embed
# codestral-embed
# codestral-embed-2505
# mistral-moderation-2411
# mistral-moderation-latest
# mistral-ocr-2512
# mistral-ocr-latest
# mistral-ocr-2505
# mistral-ocr-2503
# voxtral-mini-transcribe-2507
# voxtral-mini-2507
# voxtral-mini-latest
